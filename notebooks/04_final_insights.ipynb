# %% [markdown]
# # Task 4: Final Insights & Recommendations
# **Customer Experience Analytics for Ethiopian Mobile Banking Apps**
# **Omega Consultancy — Final Stakeholder Report**
# **Nathanael Dereje | December 2025**
#
# ___

# %% [markdown]
# ## 1. Setup and Data Loading

# %%
import sys
import os

# Add project root (one directory above "notebooks")
sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd
from scripts.utils.insights import *
import ast

# %%
df = pd.read_csv("..\data\processed\cleaned_reviews_with_themes.csv", parse_dates=["date"])
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\natty\AppData\Local\Temp\ipykernel_23128\513210522.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv("..\data\processed\cleaned_reviews_with_themes.csv", parse_dates=["date"])

# %%
# Option A — Simple and clear (just do it directly)
print("Reviews per bank:")
print(df['bank'].value_counts())

print("\nSentiment distribution:")
print(df['sentiment'].value_counts())
# Out:
# Reviews per bank:
# bank
# CBE       450
# BOA       450
# DASHEN    450
# Name: count, dtype: int64
#
# Sentiment distribution:
# sentiment
# positive    849
# negative    501
# Name: count, dtype: int64

# %%
produce_task4_outputs(df)
# Out:
# c:\Users\natty\Downloads\KAIM\fintech-app-cx-analytics\scripts\utils\insights.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top, y="theme", x="count", palette="viridis")
# c:\Users\natty\Downloads\KAIM\fintech-app-cx-analytics\scripts\utils\insights.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top, y="theme", x="count", palette="viridis")
# c:\Users\natty\Downloads\KAIM\fintech-app-cx-analytics\scripts\utils\insights.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...
